# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inlinetables = pd.read_html(
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tables = pd.read_html("http://www.childhealthdata.org/browse/survey/allstates?q=4568#")

# %%
tables[0]
# Out:
#     Unnamed: 0                 State  Underweight %  Normal weight %  \
# 0          NaN               Alabama            8.3             56.2
# 1          NaN                Alaska            5.1             68.6
# 2          NaN               Arizona            6.1             67.0
# 3          NaN              Arkansas            5.8             60.3
# 4          NaN            California            6.5             62.3
# 5          NaN              Colorado            7.6             65.2
# 6          NaN           Connecticut            6.9             62.9
# 7          NaN              Delaware            9.2             59.9
# 8          NaN  District of Columbia            5.9             60.4
# 9          NaN               Florida            3.5             59.9
# 10         NaN               Georgia            4.5             63.3
# 11         NaN                Hawaii            6.5             68.0
# 12         NaN                 Idaho            5.8             68.2
# ...

# %%
df = tables[0]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'Underweight %', 'Normal weight %',
#        'Overweight or obese %', 'Total %'],
#       dtype='object')

# %%
kidsObesity = df[['State','Overweight or obese %']]
kidsObesity.to_csv("kidsObesity")
